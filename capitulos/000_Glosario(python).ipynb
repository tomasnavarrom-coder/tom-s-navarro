# %% [markdown]
# <a href="https://colab.research.google.com/github/tomasnavarrom-coder/tom-s-navarro/blob/main/00_Glosario(python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Glosario
#
# 1. Divsion entera (`//`)
#
# >Es la division entre numeros en donde el resultado es siempre entero por lo cual se redondea siempre al entero menor.
#
#
# ---
#
# 2. Expresión
#
# >Una colección de operadores y números
#
#
# ---
#
# 3. Valor
#
# >Es el resultado de una expresión
#
# ---
#
#
# 4. Error: SyntaxError
#
# >Ocurre cuando llamo una función y cometo un error en su escritura (por ejemplo: abs 56, es un error pues no puse los parentesis e el 56)
#
# ---
#
#
# 5. Función `len()`
#
# >Cuenta la cantidad de caracteres que tiene un string. Si no pongo los parentesis tengo un error de sintaxis
#
# ---
#
#
# 6. Error de tipo (TypeError)
#
# >Cuando se ejecuta una operacion que no está asociada a un tipo. (Ejemplo: dividir un string pues con string solo puedo * y +)
#
# ---
#
#
# 7.Debugging
#
# >Es el proceso de encontrar y corregir errores
#
# ---
#
#
# 8.
#
# >
#
# ---
#
#
# 9.
